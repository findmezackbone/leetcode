# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nums = [1,2,3,4,5,6,7]

# %%
nums = nums[-1:]+nums[:-1]
print(nums)
# Out:
# [6, 7, 1, 2, 3, 4, 5]

# %%
#取余操作
a = 5
b = 2
a % b = 1
a // b = 2
a / b = 2.5
