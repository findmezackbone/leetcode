# %%
b = 1
a = b
a -= 1
print(a)
print(b)
# Out:
# 0
# 1

# %%
import heapq

a = [8,1,2,3,4,5]
b = [-x for x in a]
heapq.heapify(b)

print(b)
# Out:
# [-8, -4, -5, -3, -1, -2]

# %%
print(a)
# Out:
# None
